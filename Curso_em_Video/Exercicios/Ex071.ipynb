# %%
# Crie um programa que simule o funcionamento de um caixa eletrônico. 
# No início, pergunte ao usuário qual será o valor a ser sacado (número inteiro) e o programa vai informar quantas cédulas de cada valor serão entregues.

#OBS: considere que o caixa possui cédulas de R$50, R$20, R$10 e R$1.

resto = cedulas = 0

print('='*40)
print('{:^40}'.format('BANCO ANDY'))
print('='*40)
valor = int(input('Qual valor você quer sacar? R$'))
resto = valor

while True:
    if resto // 50 > 0:
        cedulas = resto // 50
        resto = resto % 50
        print(f'Total de {cedulas} cédulas de R$50')
    elif resto // 20 > 0:
        cedulas = resto // 20
        resto = resto % 20
        print(f'Total de {cedulas} cédulas de R$20')
    elif resto // 10 > 0:
        cedulas = resto // 10
        resto = resto % 10
        print(f'Total de {cedulas} cédulas de R$10')
    elif resto // 1 > 0:
        cedulas = resto // 1
        resto = resto % 1
        print(f'Total de {cedulas} cédulas de R$1')
    else:
        break
print('='*40)
print('Volte sempre ao BANCO ANDY! Tenha um bom dia!')

resto = valor

while True:
    if resto // 200 > 0:
        cedulas = valor // 200
        resto = resto % 200
        print(f'Total de {cedulas} cédulas de R$200')
    elif resto // 100 > 0:
        cedulas = resto // 100
        resto = resto % 100
        print(f'Total de {cedulas} cédulas de R$100')
    elif resto // 50 > 0:
        cedulas = resto // 50
        resto = resto % 50
        print(f'Total de {cedulas} cédulas de R$50')
    elif resto // 20 > 0:
        cedulas = resto // 20
        resto = resto % 20
        print(f'Total de {cedulas} cédulas de R$20')
    elif resto // 10 > 0:
        cedulas = resto // 10
        resto = resto % 10
        print(f'Total de {cedulas} cédulas de R$10')
    elif resto // 5 > 0:
        cedulas = resto // 5
        resto = resto % 5
        print(f'Total de {cedulas} cédulas de R$5')
    elif resto // 2 > 0:
        cedulas = resto // 2
        resto = resto % 2
        print(f'Total de {cedulas} cédulas de R$2')
    elif resto // 1 > 0:
        cedulas = resto // 1
        resto = resto % 1
        print(f'Total de {cedulas} cédulas de R$1')
    else:
        break
print('='*40)
print('Volte sempre ao BANCO ANDY! Tenha um bom dia!')
# Out:
# ========================================
#                BANCO ANDY
# ========================================
# Qual valor você quer sacar? R$1596
# Total de 31 cédulas de R$50
# Total de 2 cédulas de R$20
# Total de 6 cédulas de R$1
# ========================================
# Volte sempre ao BANCO ANDY! Tenha um bom dia!
# Total de 7 cédulas de R$200
# Total de 1 cédulas de R$100
# Total de 1 cédulas de R$50
# Total de 2 cédulas de R$20
# Total de 1 cédulas de R$5
# Total de 1 cédulas de R$1
# ========================================
# Volte sempre ao BANCO ANDY! Tenha um bom dia!
