# %%
# Aprimore o desafio 93 para que ele funcione com vários jogadores, incluindo um sistema de visualização de detalhes do aproveitamento de cada jogador.

tot = 0
dic = dict()
lista = list()
listaF = list()

while True:
    dic['nome'] = input('Nome: ').strip().capitalize()
    partidas = int(input(f'Quantas partidas {dic["nome"]} jogou? '))
    for g in range(0, partidas):
        lista.append(int(input(f'Quantos gols na partida {g}? ')))
        tot += lista[g]
    dic['gols'] = lista[:]
    dic['total'] = tot
    listaF.append(dic.copy())
    lista.clear()
    tot = 0
    r = input('Quer continuar? [S/N] ').strip().upper()[0]
    while r not in 'SN':
        r = input('Inserção inválida, tente novamente. \nQuer continuar? [S/N] ').strip().upper()[0]
    if r == 'N':
        break
    print('-' * 30)
print('-='*30)
print(f'{"cod":<5}{"nome":<15}{"gols":<15}{"total":<5}')
print('-'*40)
for n, i in enumerate(listaF):
    for v in i.values():
        print(f'{n:^5}{i["nome"]:<15}{str(i["gols"]):<15}{i["total"]:<5}')
        break
print('-'*40)
while True:
    show = int(input('Mostrar dados de qual jogador? [999 para encerrrar] '))
    if show == 999:
        break
    if show >= len(listaF) or 0 > show:
        print(f'ERRO! Não existe jogador com código {show}! Tente novamente.')
    else:
        print(f'-- LEVANTAMENTO DO JOGADOR {listaF[show]["nome"]}:')
        for n, i in enumerate(listaF[show]["gols"]):
            print(f'No jogo {n+1} fez {i} gols.')
    print('-' * 40)
print("<< VOLTE SEMPRE >>")
# Out:
# Nome: Ronaldinho
# Quantas partidas Ronaldinho jogou? 3
# Quantos gols na partida 0? 2
# Quantos gols na partida 1? 3
# Quantos gols na partida 2? 2
# Quer continuar? [S/N] s
# ------------------------------
# Nome: Ronaldo
# Quantas partidas Ronaldo jogou? 2
# Quantos gols na partida 0? 3
# Quantos gols na partida 1? 1
# Quer continuar? [S/N] s
# ------------------------------
# Nome: Vanpeta
# Quantas partidas Vanpeta jogou? 4
# Quantos gols na partida 0? 0
# Quantos gols na partida 1? 0
# Quantos gols na partida 2? 2
# Quantos gols na partida 3? 2
# Quer continuar? [S/N] s
# ------------------------------
# Nome: Caca
# Quantas partidas Caca jogou? 1
# Quantos gols na partida 0? 3
# Quer continuar? [S/N] n
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# cod  nome           gols           total
# ----------------------------------------
#   0  Ronaldinho     [2, 3, 2]      7
#   1  Ronaldo        [3, 1]         4
#   2  Vanpeta        [0, 0, 2, 2]   4
#   3  Caca           [3]            3
# ----------------------------------------
# Mostrar dados de qual jogador? [999 para encerrrar] 0
# -- LEVANTAMENTO DO JOGADOR Ronaldinho:
# No jogo 0 fez 2 gols.
# No jogo 1 fez 3 gols.
# No jogo 2 fez 2 gols.
# ----------------------------------------
# Mostrar dados de qual jogador? [999 para encerrrar] 2
# -- LEVANTAMENTO DO JOGADOR Vanpeta:
# No jogo 0 fez 0 gols.
# No jogo 1 fez 0 gols.
# No jogo 2 fez 2 gols.
# No jogo 3 fez 2 gols.
# ----------------------------------------
# Mostrar dados de qual jogador? [999 para encerrrar] 8
# ERRO! Não existe jogador com código 8! Tente novamente.
# ----------------------------------------
# Mostrar dados de qual jogador? [999 para encerrrar] 999
# << VOLTE SEMPRE >>
