# %%
# Crie um pequeno sistema modularizado que permita cadastrar pessoas pelo seu nome e idade em um arquivo de texto simples.
# O sistema só vai ter 2 opções: cadastar uma nova pessoa e listar todas as pessoas cadastradas.

from Banco import *
from Menus import *
from time import sleep

resp = 0

while True:
    resp = mainMenu()
    if resp == 1:
        mostrar()
        sleep(2)
        
    elif resp == 2:
        armazenar()
        sleep(2)
        
    elif resp == 3:
        titulo("Saindo do sistema... Até logo!")
        break
# Out:
# --------------------------------------------------
#                   MENU PRINCIPAL
# --------------------------------------------------
# 1 - Ver pessoas cadastradas
# 2 - Cadastrar nova Pessoa
# 3 - Sair do Sistema
# --------------------------------------------------
# Sua Opção: 1
# --------------------------------------------------
#                PESSOAS CADASTRADAS
# --------------------------------------------------
# Alan Nogueira                             85 anos
# Beatriz Leixley                           65 anos
# Santhiago Freitas                          9 anos
# Brithgtney Yosgheter                      88 anos
# Igor Freitas                              10 anos
# TÃ¢nia Vargues                            58 anos
# Tamantha Iorgues                          56 anos
# Igor Lhamis                                2 anos
# --------------------------------------------------
#                   MENU PRINCIPAL
# --------------------------------------------------
# 1 - Ver pessoas cadastradas
# 2 - Cadastrar nova Pessoa
# 3 - Sair do Sistema
# --------------------------------------------------
# Sua Opção: 2
# --------------------------------------------------
#                   NOVO CADASTRO
# --------------------------------------------------
# Nome: Ana Julia
# Idade: 14
# Registro de Ana Julia adicionado.
# --------------------------------------------------
#                   MENU PRINCIPAL
# --------------------------------------------------
# 1 - Ver pessoas cadastradas
# 2 - Cadastrar nova Pessoa
# 3 - Sair do Sistema
# --------------------------------------------------
# Sua Opção: 1
# --------------------------------------------------
#                PESSOAS CADASTRADAS
# --------------------------------------------------
# Alan Nogueira                             85 anos
# Beatriz Leixley                           65 anos
# Santhiago Freitas                          9 anos
# Brithgtney Yosgheter                      88 anos
# Igor Freitas                              10 anos
# TÃ¢nia Vargues                            58 anos
# Tamantha Iorgues                          56 anos
# Igor Lhamis                                2 anos
# Ana Julia                                 14 anos
# --------------------------------------------------
#                   MENU PRINCIPAL
# --------------------------------------------------
# 1 - Ver pessoas cadastradas
# 2 - Cadastrar nova Pessoa
# 3 - Sair do Sistema
# --------------------------------------------------
# Sua Opção: 3
# --------------------------------------------------
#           Saindo do sistema... Até logo!
# --------------------------------------------------
